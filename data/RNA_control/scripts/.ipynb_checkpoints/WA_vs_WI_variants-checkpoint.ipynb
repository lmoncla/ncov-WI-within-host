# %% [markdown]
# # Wisconsin variants called using Wisconsin pipeline vs Washington pipeline
#
# **Date**: written 2021-01-28
# **Author**: Katarina Braun
#
#
# ## Overview
#
# Here we are going to compare variants called using the Wisconsin pipeline and the Washington pipeline. We want to make sure there is a relatively high percent overlap here.
#
# ### input
#
# - `../data/WI_vs_WA/WI_variants_from_WA_pipeline/*`
# - `../data/WI_vs_WA/WI_variants_from_WI_pipeline/*`
#
# ### figure
#
# - `../figures/WI_vs_WA.png`

# %% [markdown]
# ### import modules and dependencies

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn import preprocessing
import matplotlib.pyplot as plt
import glob
import os
from matplotlib import pyplot
import matplotlib.pyplot as plt
from pathlib import Path
from os.path import splitext
from functools import reduce
from pandas.api.types import is_numeric_dtype
import warnings
from pandas.core.common import SettingWithCopyWarning
from matplotlib.font_manager import FontProperties 
from matplotlib import cm
import itertools
from matplotlib import container
from matplotlib import gridspec
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import matplotlib.lines as mlines
import matplotlib as mpl
from pandas.plotting import table
import seaborn as sns
from scipy import stats

# %% [markdown]
# ## data cleaning

# %% [markdown]
# ### define functions for data cleaning -- this will clean WA VCFs

# %%
# get a list of filenames without the extension from some directory 
# example usage: `get_files('../data_derived/SNV', 'VCFlist')`
def get_files(path): 
    filelist = [os.path.splitext(filename)[0] for filename in os.listdir(path)]
    filelist.remove('.DS_Store')
    return(filelist)
#     print(filelist)

# load all text files in a directory into Pandas dataframes 
def load_dataframes(path):
    filelist = [os.path.splitext(file)[0] for file in os.listdir(path) if file.endswith('.vcf')]
    list_of_DFs = []
    for file in filelist: 
        DF = path + '/' + file + '.vcf'
        file = pd.read_csv(DF, header=0, sep='\t', low_memory=False, skiprows=23)
        list_of_DFs.append(file)
    print(filelist)
    return(list_of_DFs)

# manipulate SNV dataframes 
# first run load_dataframes and generate a variable for the list of DFs, then feed that variable 
# into this function to clean the dataframe up and save to new CSV 
def clean_dataframes(path, list_of_DFs):
    for DF in list_of_DFs:
        sample = DF.columns[9]
        DF2 = DF.drop(['#CHROM', 'ID', 'QUAL', 'FILTER', 'FORMAT'], axis=1)
        DF2 = DF2[['POS', 'REF', 'ALT']] #POS, REF, ALT
        DF3 = DF[sample].str.split(':', expand=True) #nothing here (just need this DF to expand column 26)
        DF5 = DF3[[6]]
        DF = pd.concat([DF2, DF5], axis=1, join='inner')
        DF['SNP'] = DF['REF'] + '_' + DF['ALT'] + '_' + DF['POS'].astype(str)
        DF[6] = DF[6].str.replace(r'%', '')
        DF[6] = DF[6].astype(float)
        DF[6] = DF[6].div(100)
        DF = DF.rename(columns={6:'FREQ'})
        DF = DF[['SNP', 'FREQ']]
        DF.to_csv('../data/WI_vs_WA/compare/' + sample + '_WA.csv', sep='\t')
#

# %% [markdown]
# #### VCF file data-cleaning

# %%
# generate a list of dataframes, loaded from Illumina VCF files 
list_of_DFs = load_dataframes('../data/WI_vs_WA/WI_variants_from_WA_pipeline/')
# Out:
# ['1P_rep1', '1P_rep2', '6P_rep1', '6P_rep2', '12_rep1', '12_rep2', '12P_rep1', '12P_rep2', '17_rep1', '17_rep2', '24P_rep1', '24P_rep2', '26P_rep1', '26P_rep2', '29P_rep1', '29P_rep2', '30_rep1', '30_rep2', '31_rep1', '31_rep2', '32_rep1', '32_rep2', '44_rep1', '44_rep2', '46_rep1', '46_rep2', '51_rep1', '51_rep2', '53_rep1', '53_rep2', '55_rep1', '55_rep2', '56_rep1', '56_rep2', '57_rep1', '57_rep2', '60_rep1', '60_rep2', '80_rep1', '80_rep2', '94_rep1', '94_rep2', '99_rep1', '99_rep2', '124_rep1', '124_rep2', '125_rep1', '125_rep2', '139_rep1', '139_rep2', '148_rep1', '148_rep2', '151_rep1', '151_rep2', '158_rep1', '158_rep2', '168_rep1', '168_rep2', '172_rep1', '172_rep2', '175_rep1', '175_rep2', '182_rep1', '182_rep2', '218_rep1', '218_rep2', '229_rep1', '229_rep2', '245_rep1', '245_rep2', '249_rep1', '249_rep2', '252_rep1', '252_rep2', '255_rep1', '255_rep2', '258_rep1', '258_rep2', '261_rep1', '261_rep2', '268_rep1', '268_rep2', '270_rep1', '270_rep2', '275_rep1', '275_rep2', '276_rep1', '276_rep2', '277_rep1', '277_rep2', '283_rep1', '283_rep2', '288_rep1', '288_rep2', '289_rep1', '289_rep2', '290_rep1', '290_rep2', '292_rep1', '292_rep2', '310_rep1', '310_rep2', '338_rep1', '338_rep2', '356_rep1', '356_rep2', '358_rep1', '358_rep2', '359_rep1', '359_rep2', '361_rep1', '361_rep2', '365_rep1', '365_rep2', '366_rep1', '366_rep2', '370_rep1', '370_rep2', '374_rep1', '374_rep2', '376_rep1', '376_rep2', '377_rep1', '377_rep2', '388_rep1', '388_rep2', '391_rep1', '391_rep2', '397_rep1', '397_rep2', '402_rep1', '402_rep2', '408_rep1', '408_rep2', '418_rep1', '418_rep2', '437_rep1', '437_rep2', '468_rep1', '468_rep2', '469_rep1', '469_rep2', 'A_rep1', 'A_rep2', 'B_rep1', 'B_rep2']

# %%
# clean up all of the dataframes and save to new CSV files 
clean_dataframes('../data/WI_vs_WA/WI_variants_from_WI_pipeline/', list_of_DFs)

# %% [markdown]
# ### define functions for data cleaning -- this will clean WI VCFs

# %%
# get a list of filenames without the extension from some directory 
def get_files(path): 
    filelist = [os.path.splitext(filename)[0] for filename in os.listdir(path)]
    filelist.remove('.DS_Store')
    return(filelist)
#     print(filelist)

# load all text files in a directory into Pandas dataframes 
def load_dataframes(path):
    filelist = [os.path.splitext(file)[0] for file in os.listdir(path) if file.endswith('.vcf')]
    list_of_DFs = []
    for file in filelist: 
        DF = path + '/' + file + '.vcf'
        file = pd.read_csv(DF, header=0, sep='\t', low_memory=False, skiprows=56)
        list_of_DFs.append(file)
    print(filelist)
    return(list_of_DFs)

def load_filered_dataframes(path):
    filelist = [os.path.splitext(file)[0] for file in os.listdir(path) if file.endswith('.vcf.recode.vcf')]
    list_of_DFs = []
    for file in filelist: 
        DF = path + '/' + file + '.vcf'
        file = pd.read_csv(DF, header=0, sep='\t', low_memory=False, skiprows=56)
        list_of_DFs.append(file)
    print(filelist)
    return(list_of_DFs)

# into this function to clean the dataframe up and save to new CSV 
def clean_dataframes(path, list_of_DFs):
    if not os.path.exists(path + '/cleaned'):
            os.makedirs(path + '/cleaned')
    for DF in list_of_DFs:
        sample = DF.columns[9]
        DF2 = DF.drop(['#CHROM', 'ID', 'QUAL', 'FILTER', 'FORMAT'], axis=1)
        DF2 = DF2[['POS', 'REF', 'ALT']] #POS, REF, ALT
        DF3 = DF['INFO'].str.split(';', expand=True) #nothing here (just need this DF to expand column 26)
        DF5 = DF3[[12]] #SNP frequency 
        DF5 = DF5.rename(columns={12:'FREQ'})
        DF4 = DF3[26].str.split('|', expand=True) #1=annotation, 3=gene, 9=nt_change, 10=aa_change
        DF4 = DF4[[1,3,9,10]]
        DF4 = DF4.rename(columns={1:'annotation', 3:'gene', 9:'nt_change', 10:'aa_change'})
        DF = pd.concat([DF2, DF4, DF5], axis=1, join='inner')
        DF['FREQ'].replace(regex=True, inplace=True, to_replace=r'AF=', value='')
        DF['nt_change'].replace(regex=True, inplace=True, to_replace=r'c.', value='')
        DF['nt_change'] = DF['nt_change'].str.replace('\d+', '') # get rid of POS in nt_change column 
        DF['aa_change'].replace(regex=True, inplace=True, to_replace=r'p.', value='')
        DF['annotation'].replace(regex=True, inplace=True, to_replace=r'_variant', value='')
        DF['annotation'].replace(regex=True, inplace=True, to_replace=r'_gained', value='')
        DF['annotation'].replace(regex=True, inplace=True, to_replace=r'_', value='-')
        DF['nt_change'].replace(regex=True, inplace=True, to_replace=r'_', value='-')
        DF['aa_change'].replace(regex=True, inplace=True, to_replace=r'_', value='-')
        DF['SNP'] = DF['REF'] + '_' + DF['ALT'] + '_' + DF['POS'].astype(str)
        DF["FREQ"] = pd.to_numeric(DF["FREQ"]) #convert FREQ column from object type to int
        DF = DF[['SNP', 'FREQ']]
        DF = DF[DF.FREQ >= 0.03]
        DF.to_csv('../data/WI_vs_WA/compare/' + sample + '_WI.csv', sep='\t')

# %%
# generate a list of dataframes, loaded from Illumina VCF files 
list_of_DFs = load_dataframes('../data/WI_vs_WA/WI_variants_from_WI_pipeline/')
# Out:
# ['1P_rep1', '1P_rep2', '5_rep1', '5_rep2', '6_rep1', '6_rep2', '6P_rep1', '6P_rep2', '8_rep1', '8_rep2', '12_rep1', '12_rep2', '12P_rep1', '12P_rep2', '17_rep1', '17_rep2', '18_rep1', '18_rep2', '20_rep1', '20_rep2', '24P_rep1', '24P_rep2', '25_rep1', '25_rep2', '26P_rep1', '26P_rep2', '28_rep1', '28_rep2', '29P_rep1', '29P_rep2', '30_rep1', '30_rep2', '31_rep1', '32_rep1', '32_rep2', '44_rep1', '44_rep2', '46_rep1', '46_rep2', '50_rep1', '50_rep2', '51_rep1', '51_rep2', '53_rep1', '53_rep2', '54_rep1', '54_rep2', '55_rep1', '55_rep2', '56_rep1', '56_rep2', '57_rep1', '57_rep2', '60_rep1', '60_rep2', '61_rep1', '61_rep2', '64_rep1', '64_rep2', '65_rep1', '74_rep1', '74_rep2', '80_rep1', '80_rep2', '81_rep1', '81_rep2', '82_rep1', '82_rep2', '94_rep1', '94_rep2', '99_rep1', '99_rep2', '117_rep1', '117_rep2', '118_rep1', '118_rep2', '124_rep1', '124_rep2', '125_rep1', '125_rep2', '127_rep1', '127_rep2', '128_rep1', '128_rep2', '130_rep1', '130_rep2', '139_rep1', '139_rep2', '148_rep1', '148_rep2', '151_rep1', '151_rep2', '158_rep1', '158_rep2', '168_rep1', '168_rep2', '172_rep1', '172_rep2', '175_rep1', '175_rep2', '176_rep1', '176_rep2', '182_rep1', '188_rep1', '188_rep2', '195_rep1', '195_rep2', '196_rep1', '196_rep2', '197_rep1', '197_rep2', '218_rep1', '218_rep2', '229_rep1', '229_rep2', '245_rep1', '245_rep2', '249_rep1', '249_rep2', '252_rep1', '252_rep2', '255_rep1', '258_rep1', '258_rep2', '261_rep1', '261_rep2', '268_rep1', '268_rep2', '270_rep1', '270_rep2', '275_rep1', '275_rep2', '276_rep1', '276_rep2', '277_rep1', '277_rep2', '283_rep1', '283_rep2', '288_rep1', '288_rep2', '289_rep1', '289_rep2', '290_rep1', '290_rep2', '292_rep1', '292_rep2', '302_rep1', '302_rep2', '303_rep1', '303_rep2', '304_rep1', '304_rep2', '310_rep1', '310_rep2', '338_rep1', '338_rep2', '356_rep1', '356_rep2', '358_rep1', '358_rep2', '359_rep1', '359_rep2', '361_rep1', '361_rep2', '365_rep1', '365_rep2', '366_rep1', '366_rep2', '370_rep1', '370_rep2', '374_rep1', '374_rep2', '376_rep1', '376_rep2', '377_rep1', '377_rep2', '388_rep1', '388_rep2', '391_rep1', '391_rep2', '397_rep1', '397_rep2', '402_rep1', '402_rep2', '408_rep1', '408_rep2', '418_rep1', '418_rep2', '437_rep1', '437_rep2', '453_rep1', '453_rep2', '454_rep1', '454_rep2', '461_rep1', '461_rep2', '462_rep1', '462_rep2', '468_rep1', '468_rep2', '469_rep1', '469_rep2', '552_rep1', '552_rep2', '554_rep1', '554_rep2', '735_rep1', '735_rep2', '736_rep1', '736_rep2', '830_rep1', '830_rep2', '1113_rep1', '1113_rep2', 'A_rep1', 'A_rep2', 'B_rep1', 'B_rep2']

# %%
clean_dataframes('../data/WI_vs_WA/WI_variants_from_WI_pipeline/', list_of_DFs)

# %%
# load all intersection files in a directory into Pandas dataframes 
def load_dataframes(path):
    filelist = [os.path.splitext(file)[0] for file in os.listdir(path) if file.endswith('.csv')]
    list_of_DFs = []
    list_of_DF_names = []
    for file in filelist: 
        fullname = path + '/' + file + '.csv'
        DF = pd.read_csv(fullname, header=0, sep='\t', low_memory=False)
        DF.name = file 
        list_of_DF_names.append(file)
        list_of_DFs.append(DF)
#     print(list_of_DF_names)
    return(list_of_DFs)

# %%
WI = load_dataframes('../data/WI_vs_WA/compare/')

# %%
def find_intersection(path, df_list):
    # create list of unique dataframe identifiers – this enables easy pairing of csvs
    value_list=[]
    value_set=[]
    for item in df_list:
        if "WI" in item:
            value = item.replace("_WI.csv","")
        if "WA" in item:
            value = item.replace("_WA.csv","")
            value_list.append(value)
#             print(value_list)
        value_set=set(value_list)   
#             print(value_list)
    for item in value_set:
        # create dataframes from csv files
        WI_path = path + item + '_WI.csv'
        WI_df = pd.read_csv(WI_path, sep='\t')
        WA_path = path + item + '_WA.csv'
        WA_df = pd.read_csv(WA_path, sep='\t')
        # clean up column names
        WI_df = WI_df.rename(columns={'FREQ': '%-WI'})
        WA_df = WA_df.rename(columns={'FREQ': '%-WA'})
        A1_1m = WI_df[['SNP', '%-WI']]
        B1_1m = WA_df[['SNP', '%-WA']]
        df1_1 = pd.merge(A1_1m, B1_1m, on='SNP', how='outer')
#         df1_1['POS_x'] = df1_1['POS_x'].fillna(df1_1['POS_y'])
        df1_1 = df1_1[['SNP', '%-WI', '%-WA']]
#         df1_1 = df1_1.sort_values('POS_x', ascending=True)
        df1_1['FREQ'] = df1_1[['%-WI', '%-WA']].mean(axis=1)
        df1_1 = df1_1.rename(columns={'%-WI': 'WI_percent', '%-WA': 'WA_percent'})
        df1_1.loc[df1_1.FREQ >= 0.97, 'FREQ'] = 1.0 # any SNVs average >0.97 FREQ are likely fixed so I'll rewrite anything >0.97 to 1.0
        df1_1 = df1_1.rename(columns={'FREQ': '%'})
        df1_1_intersection = df1_1.dropna()
#         print(df1_1_intersection)
        df1_1_intersection.to_csv('../data/WI_vs_WA/intersection/'+ item + 'intersection.csv', sep='\t')
    
    #

# %%
# %%bash
#
# cp '../data/WI_vs_WA/compare/1P-rep1_WA.csv' '../data/WI_vs_WA/compare/1P_rep1_WA.csv'

# %%
# %%bash
#
# # remove the samples where there are not replicates across WI and WA
#
# rm '../data/WI_vs_WA/compare/5_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/5_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/6_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/6_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/8_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/8_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/18_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/18_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/20_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/20_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/25_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/25_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/28_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/28_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/31_rep2_WA.csv'
# rm '../data/WI_vs_WA/compare/50_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/50_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/54_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/54_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/61_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/61_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/64_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/64_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/65_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/74_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/74_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/81_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/81_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/82_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/82_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/117_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/117_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/118_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/118_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/127_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/127_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/128_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/128_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/130_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/130_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/176_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/176_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/188_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/188_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/182_rep2_WA.csv'
# rm '../data/WI_vs_WA/compare/195_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/195_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/196_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/196_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/197_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/197_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/255_rep2_WA.csv'
# rm '../data/WI_vs_WA/compare/302_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/302_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/303_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/303_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/304_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/304_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/453_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/453_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/454_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/454_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/461_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/461_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/462_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/462_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/552_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/552_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/554_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/554_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/735_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/735_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/736_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/736_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/830_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/830_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/1113_rep1_WI.csv'
# rm '../data/WI_vs_WA/compare/1113_rep2_WI.csv'
# rm '../data/WI_vs_WA/compare/1P-rep1_WA.csv'
#
# #

# %%
# make a list of the cleaned CSV files 
directory = '../data/WI_vs_WA/compare/'
files_dir =  os.listdir(directory)
newlist = []
for names in files_dir:
    if names.endswith(".csv"):
        newlist.append(names)
print(newlist)
# Out:
# ['1P_rep2_WA.csv', '6P_rep1_WA.csv', '6P_rep2_WA.csv', '12_rep1_WA.csv', '12_rep2_WA.csv', '12P_rep1_WA.csv', '12P_rep2_WA.csv', '17_rep1_WA.csv', '17_rep2_WA.csv', '24P_rep1_WA.csv', '24P_rep2_WA.csv', '26P_rep1_WA.csv', '26P_rep2_WA.csv', '29P_rep1_WA.csv', '29P_rep2_WA.csv', '30_rep1_WA.csv', '30_rep2_WA.csv', '31_rep1_WA.csv', '32_rep1_WA.csv', '32_rep2_WA.csv', '44_rep1_WA.csv', '44_rep2_WA.csv', '46_rep1_WA.csv', '46_rep2_WA.csv', '51_rep1_WA.csv', '51_rep2_WA.csv', '53_rep1_WA.csv', '53_rep2_WA.csv', '55_rep1_WA.csv', '55_rep2_WA.csv', '56_rep1_WA.csv', '56_rep2_WA.csv', '57_rep1_WA.csv', '57_rep2_WA.csv', '60_rep1_WA.csv', '60_rep2_WA.csv', '80_rep1_WA.csv', '80_rep2_WA.csv', '94_rep1_WA.csv', '94_rep2_WA.csv', '99_rep1_WA.csv', '99_rep2_WA.csv', '124_rep1_WA.csv', '124_rep2_WA.csv', '125_rep1_WA.csv', '125_rep2_WA.csv', '139_rep1_WA.csv', '139_rep2_WA.csv', '148_rep1_WA.csv', '148_rep2_WA.csv', '151_rep1_WA.csv', '151_rep2_WA.csv', '158_rep1_WA.csv', '158_rep2_WA.csv', '168_rep1_WA.csv', '168_rep2_WA.csv', '172_rep1_WA.csv', '172_rep2_WA.csv', '175_rep1_WA.csv', '175_rep2_WA.csv', '182_rep1_WA.csv', '218_rep1_WA.csv', '218_rep2_WA.csv', '229_rep1_WA.csv', '229_rep2_WA.csv', '245_rep1_WA.csv', '245_rep2_WA.csv', '249_rep1_WA.csv', '249_rep2_WA.csv', '252_rep1_WA.csv', '252_rep2_WA.csv', '255_rep1_WA.csv', '258_rep1_WA.csv', '258_rep2_WA.csv', '261_rep1_WA.csv', '261_rep2_WA.csv', '268_rep1_WA.csv', '268_rep2_WA.csv', '270_rep1_WA.csv', '270_rep2_WA.csv', '275_rep1_WA.csv', '275_rep2_WA.csv', '276_rep1_WA.csv', '276_rep2_WA.csv', '277_rep1_WA.csv', '277_rep2_WA.csv', '283_rep1_WA.csv', '283_rep2_WA.csv', '288_rep1_WA.csv', '288_rep2_WA.csv', '289_rep1_WA.csv', '289_rep2_WA.csv', '290_rep1_WA.csv', '290_rep2_WA.csv', '292_rep1_WA.csv', '292_rep2_WA.csv', '310_rep1_WA.csv', '310_rep2_WA.csv', '338_rep1_WA.csv', '338_rep2_WA.csv', '356_rep1_WA.csv', '356_rep2_WA.csv', '358_rep1_WA.csv', '358_rep2_WA.csv', '359_rep1_WA.csv', '359_rep2_WA.csv', '361_rep1_WA.csv', '361_rep2_WA.csv', '365_rep1_WA.csv', '365_rep2_WA.csv', '366_rep1_WA.csv', '366_rep2_WA.csv', '370_rep1_WA.csv', '370_rep2_WA.csv', '374_rep1_WA.csv', '374_rep2_WA.csv', '376_rep1_WA.csv', '376_rep2_WA.csv', '377_rep1_WA.csv', '377_rep2_WA.csv', '388_rep1_WA.csv', '388_rep2_WA.csv', '391_rep1_WA.csv', '391_rep2_WA.csv', '397_rep1_WA.csv', '397_rep2_WA.csv', '402_rep1_WA.csv', '402_rep2_WA.csv', '408_rep1_WA.csv', '408_rep2_WA.csv', '418_rep1_WA.csv', '418_rep2_WA.csv', '437_rep1_WA.csv', '437_rep2_WA.csv', '468_rep1_WA.csv', '468_rep2_WA.csv', '469_rep1_WA.csv', '469_rep2_WA.csv', 'A_rep1_WA.csv', 'A_rep2_WA.csv', 'B_rep1_WA.csv', 'B_rep2_WA.csv', '1P_rep1_WI.csv', '1P_rep2_WI.csv', '6P_rep1_WI.csv', '6P_rep2_WI.csv', '12_rep1_WI.csv', '12_rep2_WI.csv', '12P_rep1_WI.csv', '12P_rep2_WI.csv', '17_rep1_WI.csv', '17_rep2_WI.csv', '24P_rep1_WI.csv', '24P_rep2_WI.csv', '26P_rep1_WI.csv', '26P_rep2_WI.csv', '29P_rep1_WI.csv', '29P_rep2_WI.csv', '30_rep1_WI.csv', '30_rep2_WI.csv', '31_rep1_WI.csv', '32_rep1_WI.csv', '32_rep2_WI.csv', '44_rep1_WI.csv', '44_rep2_WI.csv', '46_rep1_WI.csv', '46_rep2_WI.csv', '51_rep1_WI.csv', '51_rep2_WI.csv', '53_rep1_WI.csv', '53_rep2_WI.csv', '55_rep1_WI.csv', '55_rep2_WI.csv', '56_rep1_WI.csv', '56_rep2_WI.csv', '57_rep1_WI.csv', '57_rep2_WI.csv', '60_rep1_WI.csv', '60_rep2_WI.csv', '80_rep1_WI.csv', '80_rep2_WI.csv', '94_rep1_WI.csv', '94_rep2_WI.csv', '99_rep1_WI.csv', '99_rep2_WI.csv', '124_rep1_WI.csv', '124_rep2_WI.csv', '125_rep1_WI.csv', '125_rep2_WI.csv', '139_rep1_WI.csv', '139_rep2_WI.csv', '148_rep1_WI.csv', '148_rep2_WI.csv', '151_rep1_WI.csv', '151_rep2_WI.csv', '158_rep1_WI.csv', '158_rep2_WI.csv', '168_rep1_WI.csv', '168_rep2_WI.csv', '172_rep1_WI.csv', '172_rep2_WI.csv', '175_rep1_WI.csv', '175_rep2_WI.csv', '182_rep1_WI.csv', '218_rep1_WI.csv', '218_rep2_WI.csv', '229_rep1_WI.csv', '229_rep2_WI.csv', '245_rep1_WI.csv', '245_rep2_WI.csv', '249_rep1_WI.csv', '249_rep2_WI.csv', '252_rep1_WI.csv', '252_rep2_WI.csv', '255_rep1_ ...

# %%
find_intersection('../data/WI_vs_WA/compare/', newlist)

# %%
# load all intersection files in a directory into Pandas dataframes 
def load_intersection_dataframes(path):
    filelist = [os.path.splitext(file)[0] for file in os.listdir(path) if file.endswith('intersection.csv')]
    list_of_DFs = []
    list_of_DF_names = []
    for file in filelist: 
        fullname = path + '/' + file + '.csv'
        DF = pd.read_csv(fullname, header=0, sep='\t', low_memory=False)
        DF.name = file 
        list_of_DF_names.append(file)
        list_of_DFs.append(DF)
#     print(list_of_DF_names)
    return(list_of_DFs)

# %%
#list of intersection DFs
WI_vs_WA_list = load_intersection_dataframes('../data/WI_vs_WA/intersection')
# WI_vs_WA_list

# %%
def plot_WI_vs_WA(DF_list, concat_dataframe):
    # global settings 
    fig1 = plt.figure(figsize=(8,8), facecolor='w')
    plt.style.use('default')
    mpl.rc('font', family='Arial')
    gs = gridspec.GridSpec(2,10)
    
    # define subplots
    ax1 = fig1.add_subplot(gs[1,0:5], aspect='equal') # replicate plot
    ax2 = fig1.add_subplot(gs[1,5:10], aspect='equal') # replicate plot ZOOM
   
    ax1.spines['top'].set_visible(False)
    ax1.spines['right'].set_visible(False)
    ax1.spines['bottom'].set_visible(True)
    ax1.spines['left'].set_visible(True)
    ax2.spines['top'].set_visible(False)
    ax2.spines['right'].set_visible(False)
    ax2.spines['bottom'].set_visible(True)
    ax2.spines['left'].set_visible(True)
    
    # set fontsize of axes 
    ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
    ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)
    ax2.tick_params(axis = 'both', which = 'major', labelsize = 10)
    ax2.tick_params(axis = 'both', which = 'minor', labelsize = 10)

    # edit the axes - ax1
    ax1.set_ylabel('WA variant freq', fontname='Arial', fontsize=10)
    ax1.set_xlabel('WI variant freq', fontname='Arial', fontsize=10)
    ax1.set_facecolor('white')
    for tick in ax1.get_xticklabels():
        tick.set_fontname("Arial")
    for tick in ax1.get_yticklabels():
        tick.set_fontname("Arial")
    ax1.set_ylim(0.001,1.03)
    ax1.set_yticks([0, 0.25, 0.50, 0.75, 1.0])
    ax1.set_xlim(0.001,1.03)
    ax1.set_xticks([0, 0.25, 0.50, 0.75, 1.0])
    
    # edit the axes - ax2
    ax2.set_ylabel('WA variant freq 1-10%', fontname='Arial', fontsize=10)
    ax2.set_xlabel('WI variant freq 1-10%', fontname='Arial', fontsize=10)
    ax2.set_facecolor('white')
    for tick in ax2.get_xticklabels():
        tick.set_fontname("Arial")
    for tick in ax2.get_yticklabels():
        tick.set_fontname("Arial")
    ax2.set_ylim(-0.001, 0.15)
    ax2.set_yticks([0.05, 0.1, 0.15])
    ax2.set_xlim(-0.001, 0.15)
    ax2.set_xticks([0.05, 0.1, 0.15])
    
    r2 = stats.pearsonr(concat_dataframe['WI_percent'], concat_dataframe['WA_percent'])
    p = sns.jointplot(data=concat_dataframe, x='WI_percent', y='WA_percent', kind="reg", ylim=(0,1), xlim=(0,1), color='lightblue')
    p.fig.text(0.85, 0.85, r2, fontsize=12)
    
    for DF in DF_list: 
        ax1.scatter(DF.WI_percent, DF.WA_percent, color='lightblue', alpha=0.5)
        ax2.scatter(DF.WI_percent, DF.WA_percent, color='lightblue', alpha=0.5)
    
    fig1.tight_layout()
    # save this plot to the figures folder 
    fig1.savefig('../figures/WI_vs_WA/WI_vs_WA.png', bbox_inches='tight', dpi=300)
    p.savefig('../figures/WI_vs_WA/WI_vs_WA-linear-regression.png', bbox_inches='tight', dpi=300)

#

# %%
# concatenate all dataframes in the list_of_intersectoin_DFs into a single DF 

WI_vs_WA_combined = pd.concat(WI_vs_WA_list)

#

# %%
# plot intersections on a single plot to calculate lineaar correlation (I'd like to repeat this with multiple different frequency cut-offs)

plot_WI_vs_WA(WI_vs_WA_list, WI_vs_WA_combined)


#

# %%
def plot_WI_vs_WA_not_consensus(DF_list, concat_dataframe):
    # global settings 
    fig1 = plt.figure(figsize=(8,8), facecolor='w')
    plt.style.use('default')
    mpl.rc('font', family='Arial')
    gs = gridspec.GridSpec(2,10)
    
    # define subplots
    ax1 = fig1.add_subplot(gs[1,0:5], aspect='equal') # replicate plot
    ax2 = fig1.add_subplot(gs[1,5:10], aspect='equal') # replicate plot ZOOM
   
    ax1.spines['top'].set_visible(False)
    ax1.spines['right'].set_visible(False)
    ax1.spines['bottom'].set_visible(True)
    ax1.spines['left'].set_visible(True)
    ax2.spines['top'].set_visible(False)
    ax2.spines['right'].set_visible(False)
    ax2.spines['bottom'].set_visible(True)
    ax2.spines['left'].set_visible(True)
    
    # set fontsize of axes 
    ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
    ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)
    ax2.tick_params(axis = 'both', which = 'major', labelsize = 10)
    ax2.tick_params(axis = 'both', which = 'minor', labelsize = 10)

    # edit the axes - ax1
    ax1.set_ylabel('WA variant freq', fontname='Arial', fontsize=10)
    ax1.set_xlabel('WI variant freq', fontname='Arial', fontsize=10)
    ax1.set_facecolor('white')
    for tick in ax1.get_xticklabels():
        tick.set_fontname("Arial")
    for tick in ax1.get_yticklabels():
        tick.set_fontname("Arial")
    ax1.set_ylim(0.001,0.9)
    ax1.set_yticks([0, 0.25, 0.50, 0.75, 0.9])
    ax1.set_xlim(0.001,0.9)
    ax1.set_xticks([0, 0.25, 0.50, 0.75, 0.9])
    
    # edit the axes - ax2
    ax2.set_ylabel('WA variant freq 1-10%', fontname='Arial', fontsize=10)
    ax2.set_xlabel('WI variant freq 1-10%', fontname='Arial', fontsize=10)
    ax2.set_facecolor('white')
    for tick in ax2.get_xticklabels():
        tick.set_fontname("Arial")
    for tick in ax2.get_yticklabels():
        tick.set_fontname("Arial")
    ax2.set_ylim(-0.001, 0.15)
    ax2.set_yticks([0.05, 0.1, 0.15])
    ax2.set_xlim(-0.001, 0.15)
    ax2.set_xticks([0.05, 0.1, 0.15])
    
    r2 = stats.pearsonr(concat_dataframe['WI_percent'], concat_dataframe['WA_percent'])
    ax = sns.jointplot(data=concat_dataframe, x='WI_percent', y='WA_percent', kind="reg", ylim=(0,0.9), xlim=(0,0.9), color='lightblue')
    ax.fig.text(0.85, 0.85, r2, fontsize=12)               
                    
    for DF in DF_list: 
        ax1.scatter(DF.WI_percent, DF.WA_percent, color='lightblue', alpha=0.5)
        ax2.scatter(DF.WI_percent, DF.WA_percent, color='lightblue', alpha=0.5)
    
    fig1.tight_layout()
    # save this plot to the figures folder 
    fig1.savefig('../figures/WI_vs_WA/WI_vs_WA.png', bbox_inches='tight', dpi=300)
    ax.savefig('../figures/WI_vs_WA/WI_vs_WA-linear-regression.png', bbox_inches='tight', dpi=300)

#

# %%
# plot intersections on a single plot to calculate lineaar correlation (I'd like to repeat this with multiple different frequency cut-offs)

plot_WI_vs_WA_not_consensus(WI_vs_WA_list, WI_vs_WA_combined)
